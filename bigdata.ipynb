# %% [markdown]
# <a href="https://colab.research.google.com/github/nemedl/gerenciador-de-tarefas/blob/main/bigdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel("/content/drive/MyDrive/bigdata/Cópia de serviçosQTD.xlsx")
display(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-22b3c356ab1a> in <cell line: 1>()
# ----> 1 df = pd.read_excel("/content/drive/MyDrive/bigdata/Cópia de serviçosQTD.xlsx")
#       2 display(df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476     if not isinstance(io, ExcelFile):
#     477         should_close = True
# --> 478         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479     elif engine and engine != io.engine:
#     480         raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1494                 ext = "xls"
#    1495             else:
# -> 1496                 ext = inspect_excel_format(
#    1497                     content_or_path=path_or_buffer, storage_options=storage_options
#    1498                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1369         content_or_path = BytesIO(content_or_path)
#    1370
# -> 1371     with get_handle(
#    1372         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1373     ) as handle:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     866         else:
#     867             # Binary mode
# --> 868             handle = open(handle, ioargs.mode)
#     869         handles.append(handle)
#     870
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/bigdata/Cópia de serviçosQTD.xlsx'

# %%
df.describe()
# Out:
#         QUATIDADE         %
# count    8.000000  7.000000
# mean    88.000000  0.142857
# std    137.136012  0.264466
# min      1.000000  0.002800
# 25%      2.750000  0.007100
# 50%     14.500000  0.039800
# 75%    109.750000  0.107950
# max    352.000000  0.727300

# %%
df.iloc[5]
# Out:
# SERVIÇOS      CORTE
# QUATIDADE         1
# %            0.0028
# Name: 5, dtype: object

# %%
df1 = pd.read_excel("/content/drive/MyDrive/bigdata/Cópia de clientes.xlsx")
display(df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-99fbbf0c43ac> in <cell line: 1>()
# ----> 1 df1 = pd.read_excel("/content/drive/MyDrive/bigdata/Cópia de clientes.xlsx")
#       2 display(df1)
#
# NameError: name 'pd' is not defined

# %%
df1.describe()
# Out:
#            IDADE       VALOR
# count  15.000000   15.000000
# mean   50.600000  106.000000
# std     9.279778   16.604647
# min    36.000000   85.000000
# 25%    43.500000   95.000000
# 50%    50.000000  100.000000
# 75%    57.000000  110.000000
# max    66.000000  135.000000

# %%
sexo_counts = df1['SEXO'].value_counts()


total_clientes = sexo_counts.sum()


percent_masculino = (sexo_counts['M'] / total_clientes) * 100
percent_feminino = (sexo_counts['F'] / total_clientes) * 100

print(f"Porcentagem de clientes masculinos: {percent_masculino:.2f}%")
print(f"Porcentagem de clientes femininos: {percent_feminino:.2f}%")
# Out:
# Porcentagem de clientes masculinos: 86.67%
# Porcentagem de clientes femininos: 13.33%

# %%
df2 = pd.read_excel("/content/drive/MyDrive/bigdata/Cópia de REPOSIÇÃO DE FIOS1.xlsx")
display(df2)
# Out:
#                                     NOME  IDADE SEXO             BAIRRO  \
# 0   ALBERTO RICHARD XAVIER ALVES PEREIRA     55    M    BARRA DA TIJUCA
# 1               ANDERSON RICARDO MARTINS     50    M            HUMAITÁ
# 2                DANIEL BARBOSA PROCÓPIO     35    M  COMENDADOR SOARES
# 3                     DIONES MELO CHAVES     33    M             MUZEMA
# 4                           EDUARDO DIER     48    M        LARANJEIRAS
# 5                   JOAO CARLOS DA SILVA     65    M              MUTUÁ
# 6            JULIO CESAR DA SILVA BORGES     62    M           MARACANÃ
# 7       MARIA APARECIDA SANTOS DO AMARAL     55    F    BARRA DA TIJUCA
# 8                MILTON DA SILVA RIBEIRO     79    M         BONSUCESSO
# 9          MONICA FERREIRA LOPES E SOUZA     48    F             GRAJAÚ
# 10     PATRICK SENGER CARNEIRO DESCHATRE     33    M             GRAJAÚ
# 11           URUBATAN VIEIRA DE MEDERIOS     52    M            IPANEMA
# 12                 WESLEY NEVES DA SILVA     44    M    JARDIM GRAMACHO
#
#                      SERVIÇO   VALOR
# 0     1H DE REPOSIÇÃO DE FIOS    146
# 1     1H DE REPOSIÇÃO DE FIOS    146
# 2     1H DE REPOSIÇÃO DE FIOS    146
# 3     2H DE REPOSIÇÃO DE FIOS    292
# 4     1H DE REPOSIÇÃO DE FIOS    146
# 5     1H DE REPOSIÇÃO DE FIOS    146
# 6    1/2H DE REPOSIÇÃO DE FIO     73
# 7     1H DE REPOSIÇÃO DE FIOS    146
# 8     2H DE REPOSIÇÃO DE FIOS    292
# 9     1H DE REPOSIÇÃO DE FIOS    146
# 10   1/2H DE REPOSIÇÃO DE FIO     73
# 11    1H DE REPOSIÇÃO DE FIOS    146
# 12    1H DE REPOSIÇÃO DE FIOS    146

# %%
data_bairros_rio = {
    'BAIRRO': [
        'COPACABANA', 'IPANEMA', 'LEBLON', 'BOTAFOGO', 'FLAMENGO', 'TIJUCA',
        'MARACANÃ', 'CENTRO', 'SANTA TERESA', 'LARANJEIRAS', 'RECREIO DOS BANDEIRANTES',
        'BARRA DA TIJUCA', 'JACAREPAGUÁ', 'CAMPO GRANDE', 'BANGU', 'MADUREIRA',
        'MÉIER', 'VILA ISABEL', 'GÁVEA', 'SÃO CONRADO', 'GLÓRIA', 'CATETE',
        'HUMAITÁ', 'LEME', 'URCA', 'COSME VELHO', 'GRAJAÚ', 'PAQUETÁ', 'BONSUCESSO', 'MUZEMA','JARDIM GRAMACHO','MUTUÁ','COMENDADOR SOARES'
    ],
    'ZONA': [
        'ZONA SUL', 'ZONA SUL', 'ZONA SUL', 'ZONA SUL', 'ZONA SUL', 'ZONA NORTE',
        'ZONA NORTE', 'CENTRO', 'CENTRO', 'ZONA SUL', 'ZONA OESTE',
        'ZONA OESTE', 'ZONA OESTE', 'ZONA OESTE', 'ZONA OESTE', 'ZONA NORTE',
        'ZONA NORTE', 'ZONA NORTE', 'ZONA SUL', 'ZONA SUL', 'CENTRO', 'CENTRO',
        'ZONA SUL', 'ZONA SUL', 'ZONA SUL', 'ZONA SUL', 'ZONA NORTE', 'ILHAS', 'ZONA NORTE', 'ZONA OESTE','BAIXADA', 'OUTROS','BAIXADA'
    ]
}

df_bairros_rio = pd.DataFrame(data_bairros_rio)

print(df_bairros_rio)
# Out:
#                       BAIRRO        ZONA
# 0                 COPACABANA    ZONA SUL
# 1                    IPANEMA    ZONA SUL
# 2                     LEBLON    ZONA SUL
# 3                   BOTAFOGO    ZONA SUL
# 4                   FLAMENGO    ZONA SUL
# 5                     TIJUCA  ZONA NORTE
# 6                   MARACANÃ  ZONA NORTE
# 7                     CENTRO      CENTRO
# 8               SANTA TERESA      CENTRO
# 9                LARANJEIRAS    ZONA SUL
# 10  RECREIO DOS BANDEIRANTES  ZONA OESTE
# 11           BARRA DA TIJUCA  ZONA OESTE
# 12               JACAREPAGUÁ  ZONA OESTE
# 13              CAMPO GRANDE  ZONA OESTE
# 14                     BANGU  ZONA OESTE
# 15                 MADUREIRA  ZONA NORTE
# 16                     MÉIER  ZONA NORTE
# 17               VILA ISABEL  ZONA NORTE
# 18                     GÁVEA    ZONA SUL
# 19               SÃO CONRADO    ZONA SUL
# 20                    GLÓRIA      CENTRO
# 21                    CATETE      CENTRO
# 22                   HUMAITÁ    ZONA SUL
# 23                      LEME    ZONA SUL
# 24                      URCA    ZONA SUL
# 25               COSME VELHO    ZONA SUL
# 26                    GRAJAÚ  ZONA NORTE
# 27                   PAQUETÁ       ILHAS
# 28                BONSUCESSO  ZONA NORTE
# 29                    MUZEMA  ZONA OESTE
# 30           JARDIM GRAMACHO     BAIXADA
# 31                     MUTUÁ      OUTROS
# 32         COMENDADOR SOARES     BAIXADA

# %%
ClientesBairros = df2[['NOME', 'BAIRRO']]
print(ClientesBairros)
# Out:
#                                     NOME             BAIRRO
# 0   ALBERTO RICHARD XAVIER ALVES PEREIRA    BARRA DA TIJUCA
# 1               ANDERSON RICARDO MARTINS            HUMAITÁ
# 2                DANIEL BARBOSA PROCÓPIO  COMENDADOR SOARES
# 3                     DIONES MELO CHAVES             MUZEMA
# 4                           EDUARDO DIER        LARANJEIRAS
# 5                   JOAO CARLOS DA SILVA              MUTUÁ
# 6            JULIO CESAR DA SILVA BORGES           MARACANÃ
# 7       MARIA APARECIDA SANTOS DO AMARAL    BARRA DA TIJUCA
# 8                MILTON DA SILVA RIBEIRO         BONSUCESSO
# 9          MONICA FERREIRA LOPES E SOUZA             GRAJAÚ
# 10     PATRICK SENGER CARNEIRO DESCHATRE             GRAJAÚ
# 11           URUBATAN VIEIRA DE MEDERIOS            IPANEMA
# 12                 WESLEY NEVES DA SILVA    JARDIM GRAMACHO

# %%
junção_df = pd.merge(ClientesBairros, df_bairros_rio, on='BAIRRO', how='left')

# Exibir o novo DataFrame resultante
print(junção_df)
# Out:
#                                     NOME             BAIRRO        ZONA
# 0   ALBERTO RICHARD XAVIER ALVES PEREIRA    BARRA DA TIJUCA  ZONA OESTE
# 1               ANDERSON RICARDO MARTINS            HUMAITÁ    ZONA SUL
# 2                DANIEL BARBOSA PROCÓPIO  COMENDADOR SOARES     BAIXADA
# 3                     DIONES MELO CHAVES             MUZEMA  ZONA OESTE
# 4                           EDUARDO DIER        LARANJEIRAS    ZONA SUL
# 5                   JOAO CARLOS DA SILVA              MUTUÁ      OUTROS
# 6            JULIO CESAR DA SILVA BORGES           MARACANÃ  ZONA NORTE
# 7       MARIA APARECIDA SANTOS DO AMARAL    BARRA DA TIJUCA  ZONA OESTE
# 8                MILTON DA SILVA RIBEIRO         BONSUCESSO  ZONA NORTE
# 9          MONICA FERREIRA LOPES E SOUZA             GRAJAÚ  ZONA NORTE
# 10     PATRICK SENGER CARNEIRO DESCHATRE             GRAJAÚ  ZONA NORTE
# 11           URUBATAN VIEIRA DE MEDERIOS            IPANEMA    ZONA SUL
# 12                 WESLEY NEVES DA SILVA    JARDIM GRAMACHO     BAIXADA

# %%
# Contar o número de ocorrências de cada zona
contagem_zona = junção_df['ZONA'].value_counts()

# Calcular o número total de registros
total_registros = len(junção_df)

# Calcular a porcentagem de cada zona
porcentagem_zona = (contagem_zona / total_registros) * 100

# Exibir a porcentagem de cada zona
display(porcentagem_zona)
# Out:
# ZONA
# ZONA NORTE    30.769231
# ZONA OESTE    23.076923
# ZONA SUL      23.076923
# BAIXADA       15.384615
# OUTROS         7.692308
# Name: count, dtype: float64

# %%
# Definir os intervalos de idade para cada categoria
faixas_etarias = {
    'Criança': (0, 12),
    'Adolescente': (12, 18),
    'Jovem': (15, 30),
    'Adulto': (30, 60),
    'Idoso': (60, float('inf'))
}

# Função para determinar a categoria de idade de um cliente
def categorizar_idade(idade):
    for faixa, (limite_inferior, limite_superior) in faixas_etarias.items():
        if limite_inferior <= idade < limite_superior:
            return faixa
    return 'Desconhecido'

# Aplicar a função para categorizar a idade de cada cliente
df2['Faixa Etária'] = df2['IDADE'].apply(categorizar_idade)

# Contar o número de ocorrências em cada faixa etária
contagem_faixas_etarias = df2['Faixa Etária'].value_counts()

# Calcular o número total de clientes
total_clientes = len(df2)

# Calcular a porcentagem de clientes em cada faixa etária
porcentagem_faixas_etarias = (contagem_faixas_etarias / total_clientes) * 100

# Exibir a porcentagem de clientes em cada faixa etária
print(porcentagem_faixas_etarias)
# Out:
# Faixa Etária
# Adulto    76.923077
# Idoso     23.076923
# Name: count, dtype: float64
